# %%
'''
Florida International Univeristy - Data Science MS
CAP 5640 - NLP - Spring 2019
Andrea Garcia and Constanza Schubert

This will create a jsonl file that contains all entities to be identified in tweets.
Pattern file must be loaded in all files where entity patterns are required.

Steps: 
1) Create entity ruler patterns using code below.
2) Load file along with spacy 'en_core_web_sm' model. 
3) Import EntityRuler - from spacy.pipeline import EntityRuler
4) Add ruler = EntityRuler(nlp).from_disk(patternsfile)
5) Add nlp.add_pipe(ruler, before="ner")

'''


# Load libraries
import spacy
from spacy.symbols import *
from spacy.attrs import *
from spacy.pipeline import EntityRuler

# Load model
nlp = spacy.load('en_core_web_sm')

# Name of file to contain entity patterns to match
patternsfile = "entityruler_patterns.jsonl"

patterns = [
        {"label":"PRODUCT","pattern":[{"LOWER":"iphone"}]},
        {"label":"PRODUCT","pattern":[{"LOWER":"ipad"}]},
        {"label":"PRODUCT","pattern":[{"LOWER":"ipod"}]},
        {"label":"PRODUCT","pattern":[{"LOWER":"iwatch"}]},
        {"label":"PRODUCT","pattern":[{"LOWER":"imac"}]},
        {"label":"PRODUCT","pattern":[{"LOWER":"mac"}]},
        {"label":"PRODUCT","pattern":[{"LOWER":"macbook"}]},
        {"label":"PRODUCT","pattern":[{"LOWER":"applewatch"}]},
        {"label":"PRODUCT","pattern":[{"LOWER":"apple watch"}]},
        {"label":"PRODUCT","pattern":[{"LOWER":"applecharger"}]},
        {"label":"PRODUCT","pattern":[{"LOWER":"apple charger"}]},
        {"label":"PRODUCT","pattern":[{"LOWER":"airpods"}]},
        {"label":"PRODUCT","pattern":[{"LOWER":"air pod"}]},
        {"label":"PRODUCT","pattern":[{"LOWER":"airpod"}]},
        {"label":"PRODUCT","pattern":[{"LOWER":"air pods"}]},
        {"label":"PRODUCT","pattern":[{"LOWER":"applepencil"}]},
        {"label":"PRODUCT","pattern":[{"LOWER":"apple pencil"}]},
        {"label":"PRODUCT","pattern":[{"LOWER":"appletv"}]},
        {"label":"PRODUCT","pattern":[{"LOWER":"apple tv"}]},
        {"label":"PRODUCT","pattern":[{"LOWER":"kindle"}]},
        {"label":"PRODUCT","pattern":[{"LOWER":"nook"}]},
        {"label":"PRODUCT","pattern":[{"LOWER":"homepod"}]},
        {"label":"PRODUCT","pattern":[{"LOWER":"home pod"}]},
        {"label":"SERVICE","pattern":[{"LOWER":"applepay"}]},
        {"label":"SERVICE","pattern":[{"LOWER":"apple pay"}]},
        {"label":"SERVICE","pattern":[{"LOWER":"icloud"}]},
        {"label":"SOFTWARE","pattern":[{"LOWER":"ios"}]},
        {"label":"SOFTWARE","pattern":[{"LOWER":"macos"}]},
        {"label":"SOFTWARE","pattern":[{"LOWER":"android"}]},
        {"label":"ORG","pattern":[{"LOWER":"apple"}]},
        {"label":"ORG","pattern":[{"LOWER":"appl"}]},
        {"label":"ORG","pattern":[{"LOWER":"google"}]},
        {"label":"ORG","pattern":[{"LOWER":"netflix"}]},
        {"label":"SOCIAL","pattern":[{"LOWER":"snapchat"}]},
        {"label":"SOCIAL","pattern":[{"LOWER":"facebook"}]},
        {"label":"SOCIAL","pattern":[{"LOWER":"fb"}]},
        {"label":"SOCIAL","pattern":[{"LOWER":"instagram"}]},
        {"label":"SOCIAL","pattern":[{"LOWER":"ig"}]},
        {"label":"SOCIAL","pattern":[{"LOWER":"youtube"}]},
        {"label":"SHOP","pattern":[{"LOWER":"amazon"}]}]


ruler = EntityRuler(nlp)
ruler.add_patterns(patterns)
ruler.to_disk(patternsfile)
