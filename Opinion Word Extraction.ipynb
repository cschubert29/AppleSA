# %%
import pandas as pd
import numpy as np
import spacy
import itertools
import csv
import re
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.tokenizer import Tokenizer
from spacy.pipeline import EntityRuler
from spacy.attrs import *
from spacy.symbols import *
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori , association_rules
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyser = SentimentIntensityAnalyzer()

# Global Variables
infile = 'apple_cleantweets_test.csv'
nlp = spacy.load('en_core_web_sm')
patternsfile = "entityruler_patterns.jsonl"
output = 'possible_aspects.csv'
nlp.Defaults.stop_words |= {"My","the","it", "a"}
ruler = EntityRuler(nlp).from_disk(patternsfile)
nlp.add_pipe(ruler, before="ner")

# Temp variable because we need to define dictionary value
ASP = "found"


# Temp dictionary until we run data to find frequent item sets
ASPECTS = {"battery": ASP, "battery life": ASP, "screen": ASP, 
            "screen size": ASP, "picture": ASP, "picture quality": ASP,
            "photo": ASP, "photos": ASP, "photo quality": ASP, "camera": ASP,
            "voice": ASP, "voice quality": ASP, "sound": ASP,"sound quality": ASP, 
            "software": ASP, "update": ASP, "cost": ASP, "price": ASP,
            "safety": ASP, "security": ASP, "speed": ASP, "home button": ASP , 
            "interface": ASP, "support": ASP, "customer support": ASP
          }



# Import tweet file
def import_unprocessed_tweets(infile):
    # Reads file stored in global var 'infile' into dict
    # Only stores text columns 
    # Nested lists are comprised of text,hashtag pairs
    with open(infile, 'r') as lines:
        reader = csv.DictReader(lines)
        all_tweets = []
        for line in reader:
            a_tweet = []
            text = line['text']
            a_tweet.append(text)
            all_tweets.append(a_tweet)
        # Returns list of lists containing tweet text
        print("Tweet import complete!")
        return all_tweets
    
    
# Helper function 1: Find noun phrase bigrams and/or trigrams in doc depending on token index
# Assumes there are at least three words in doc 
def noun_phrase_utility(doc, i):
    #Finds noun phrases in retokenized doc
 
    zerone = ""
    twoonezero = "" 
    onezero = ""
    zeronetwo = ""
    doc_lower = [token.lower_ for token in doc]
    phrases = []
    nps_set = set()
    # First index in list
    if i == 0:
        zerone = "{0} {1}".format(doc_lower[i],doc_lower[i + 1])
    
        zeronetwo = "{0} {1} {2}".format(doc_lower[i], doc_lower[i +1],
                                          doc_lower[i + 2])
        phrases = [zerone, zeronetwo]
    
    # Second index in list when doc is longer than three words
    elif i == 1 and len(doc_lower) > 3:
        onezero = "{0} {1}".format(doc_lower[i - 1], doc_lower[i])
        
        zerone = "{0} {1}".format(doc_lower[i],doc_lower[i + 1])
    
        zeronetwo = "{0} {1} {2}".format(doc_lower[i], doc_lower[i +1],
                                          doc_lower[i + 2])
        
        phrases = [onezero, zerone, zeronetwo]
        
    # Second index in list when doc is three words long
    elif i == 1 and len(doc_lower) == 3:
        onezero = "{0} {1}".format(doc_lower[i - 1], doc_lower[i])
        
        zerone = "{0} {1}".format(doc_lower[i],doc_lower[i + 1])
        
        phrases = [onezero, zerone]
    
    # Last index in list
    elif i == (len(doc_lower) - 1):
        onezero = "{0} {1}".format(doc_lower[i - 1], doc_lower[i])
        
        twoonezero = "{0} {1} {2}".format(doc_lower[i - 2],
                                          doc_lower[i - 1], doc_lower[i]) 
        
        phrases = [onezero, twoonezero]
    
    # Second to last index in list when doc is longer than three words
    elif i == (len(doc_lower) - 2):
        onezero = "{0} {1}".format(doc_lower[i - 1], doc_lower[i])
        
        zerone = "{0} {1}".format(doc_lower[i],doc_lower[i + 1])
        
        twoonezero = "{0} {1} {2}".format(doc_lower[i - 2],
                                          doc_lower[i - 1], doc_lower[i]) 
        
        phrases = [onezero, twoonezero, zerone]
   
    # Everything else    
    else: 
        zerone = "{0} {1}".format(doc_lower[i],doc_lower[i + 1])
    
        zeronetwo = "{0} {1} {2}".format(doc_lower[i], doc_lower[i +1],
                                          doc_lower[i + 2])
        
        onezero = "{0} {1}".format(doc_lower[i - 1], doc_lower[i])
        
        twoonezero = "{0} {1} {2}".format(doc_lower[i - 2],
                                          doc_lower[i - 1], doc_lower[i]) 
        
        phrases = [onezero, twoonezero, zerone, zeronetwo]

    return phrases


# Helper function 2: Will retokenize doc to remove stop words, punctuation and spaces
def re_tokenize(doc):
    text_list = []
    for token in doc:
        if token.is_stop != True and token.is_punct != True and token.is_space != True:
            text = token.text
            text_list.append(text)
    new_doc = ' '.join(text_list)
    doc = nlp(new_doc)
    
    return doc



# Helper Function 3: Find unique multiword aspects, return aspect list
def multi_word_aspects(new_doc):
    nps_set = set()
    for token in new_doc:
            if token.pos_ == "NOUN":
                if token.lemma_ in ASPECTS:
                    poss_aspects = noun_phrase_utility(new_doc, token.i)
                    for item in poss_aspects:
                        nps_set.add(item)
  
    nps_list = list(nps_set)
    
    return nps_list


# Helper Function 4: Find unique single word aspects, return aspect list
def single_word_aspects(new_doc):
    aspect_set = set()
    for token in new_doc:
        if token.pos_ == "NOUN":
            if token.lemma_ in ASPECTS:
                aspect_set.add(token.lemma_)
                
    aspect_list = list(aspect_set)
    return aspect_list            


# FUNCTION NOT USED
def contains_word(s, w):
    return f' {w} ' in f' {s} '


# Helper Function 5: Delete words that are found to be duplicated accross single and multiword aspect lists
# Used in merge_aspects
def delete_words(deletelist, mainlist):
    # Uses list of indeces to delete items from main_list
    new_list= [aspect for aspect in mainlist if aspect not in deletelist]
    # Returns list of single aspects not found in multiword aspect list
    return new_list


# Helper Function 6: Merges single and multiword aspect lists after duplicates are removed
# Used in opinion_finder
def merge_aspects(single_aspects, multi_aspects):
    # Convert multi-word aspect list to list of single words 
    by_word_aspects = []
    for asp in multi_aspects:
        words = asp.split(' ')
        by_word_aspects.append(words)
    
    single_words = list(itertools.chain.from_iterable(by_word_aspects))
    
    # Compare single word aspects to single_words, if match found, remove word from single words
    to_delete = []
    for s in single_aspects:
        if s in single_words:
            to_delete.append(s)
            
    clean_s_aspects = delete_words(to_delete, single_aspects)
    
    mergedlist = clean_s_aspects + multi_aspects
    return mergedlist
    

# FUNCTION NOT USED
def find_root_verb(doc):
    
    root_verb = [token for token in doc if (token.dep_ == "ROOT")]
        
    return root_verb

# FUNCTION NOT USED
def find_sentiment_words(doc):
    sentiment_words = []
    sentiment_words.append(([token for token in doc if 
                                     (not token.is_stop and not token.is_punct and 
                                      (token.pos_ == "ADJ" or token.pos_ == "VERB" or token.pos_ =="ADV"))]))
    # Return list of tokens that contain sentiment according to criteria
    return sentiment_words



# Helper Function 7: Finds opinions related to aspect terms in tweet
def opinion_rules(doc):
    subj = "000"
    obj = "000"
    mod = "000"
    neg = "000"
    pairs = []
    for token in doc:
        if token.dep_ == "nsubj":
            compound = [child.text for child in token.children if (child.dep_ == "compound")]
            modifier = [child.text for child in token.children if (child.dep_ == "amod")]
            comp = ''.join(compound)
            mod = ''.join(modifier)
            if compound: 
                subj = comp + " " + token.text
            elif modifier:
                subj = mod + " " + token.text
            else:
                subj = token.text
            
            
        if token.dep_ in ("ROOT"):
            for child in token.children:
                if child.dep_  == "dobj":
                    modifier = [c.text for c in child.children if (c.dep_ == "amod")]
                    if len(modifier) > 0:
                        mod = ''.join(modifier)
                        obj = mod + " " + child.text
                    else:
                        obj = child.text
                elif child.dep_ == "acomp":
                    obj = child.text
                
                if child.dep_ == "neg":
                    neg = child.text
    if subj != "000" and obj != "000":
        pairs.append([subj,  obj])
    return pairs


# Function will return list containing aspect and opinion associated with it if there is one
def opinion_finder(doc):
    pairs = []
    for sent in doc.sents:
        ops = opinion_rules(sent)
        pairs.append(ops)
    
    op_pair = []
    for pair in pairs:
        for p in pair:
            words = ' '.join(p)
            text = words.split()
            for word in text:
                if word.lower() in ASPECTS:
                    op_pair.append(words)

    return op_pair
    

# Function identifies aspects in doc (according to aspects in dictionary) and retursn sentiment score
def aspect_sentiment(doc):
    new_doc = re_tokenize(doc) # Retokenize doc to remove stopwords, punctuation and blank spaces
    m_aspects = multi_word_aspects(new_doc) # Find multi-word aspects
    
    s_aspects = single_word_aspects(new_doc) # Find single-word aspects
    
    # Merge the two while removing duplicate aspects
    # Only multi-word aspects are kept if match is found between two lists
    final_aspects = merge_aspects(s_aspects, m_aspects)
    #print(final_aspects)
    compound_score = 0
    scores = []
    tot = 0
    if final_aspects: 
        ops = opinion_finder(doc)
        for opinion in ops:
            compound_score = analyser.polarity_scores(opinion)
            scores.append(compound_score['compound'])
    if len(scores) == 1:
        return scores[0]
    elif len(scores) > 1:
        for num in scores:
            tot = tot + num
        average  = tot / len(scores)
        return average
    elif not scores:
        return compound_score
    

# Function finds aspects score for tweet based on aspect or sentence as a whole     
def tweet_sentiment(doc):
        
        # Find aspect score for aspects in tweet, if any
        aspect_score = aspect_sentiment(doc) 
        if aspect_score == 0.0:    #Aspects found but neutral score was given, sentiment will default to sentence sentiment
            default_score = analyser.polarity_scores(doc.text)
            def_score = default_score['compound']
            #print(def_score)
            return def_score
        elif score == 0:    #No aspects found, sentiment will default to sentence sentiment
            no_asp_score = analyser.polarity_scores(doc.text)
            noas_score = no_asp_score['compound']
            #print(noas_score) 
            return noas_score
        else:
            return aspect_score
            
 
        
#Returns tweet, with its sentiment score and its entities
#Need to add aspects found on here
def senti_process(tweets):
    for tweet in tweets:
        doc = nlp(tweet[0])
        doc_ents = []
        for token in doc: 
            if token.ent_type_ in ("ORG", "PRODUCT", "SERVICE", "SOFTWARE"):
                ent = token.ent_type_
                doc_ents.append([token.text, ent])
        
        score = tweet_sentiment(doc)
        
        print(doc, score, doc_ents)
    

    
    
all_tweets = import_unprocessed_tweets(infile)
senti_process(all_tweets)

#TESTING SENTENCES
#The screen size is horrible. At least the sound quality is okay.
#The camera does such a bad job of taking pictures! But the battery life is good
#The update does not fix the issues with the pictures
#The camera does such a bad job of taking pictures! My Cannon does far better
#doc = nlp("The camera does such a bad job of taking pictures! But the battery life is good")
#score = analyser.polarity_scores("camera bad job")
#print(score)
# Out:
# Tweet import complete!
# It makes me chuckle when articles claim that the versa can compete with the Watch. I've had both and the Versa is like 15 years behind in every aspect. 0.6369 [['Versa', 'ORG']]
# This was pretty cool! Thank you for having me. And thank you to everyone who came !! Had so much fun 0.9319 []
# I'm pretty sure I just discovered that predicted the Apple Pencil in 2013? 0.6705 [['Apple', 'ORG']]
# Court rules man must be given access to husband's iCloud photos  0.0 [['iCloud', 'SERVICE']]
# Apple over ear headphones may launch this year to complement Air Pods and give Bose competition. 0.0 [['Apple', 'ORG'], ['Air', 'ORG'], ['Pods', 'ORG']]
# Hey Apple it's funny 0.4404 [['Apple', 'ORG']]
# Ha it already broke FUCK YOU Apple -0.6841 [['Apple', 'ORG']]
# Apple shares rally 0.296 [['Apple', 'ORG']]
# iPhone 11 concept hype continues as latest video offers more realistic vision of triple camera unit 0.3134 [['iPhone', 'PRODUCT']]
# First time traveling without a headphone jack. Best case scenario: the dongle is lost in my bag during hour 5. Worst case: dongle is gone 5 hrs into the trip Wtf -0.9269 []
# The launch of the original iPad on January 27 0.3182 [['iPad', 'PRODUCT']]
# Apple may be headed for 'serious ramifications' in China after Tencent's latest update to WeChat -0.0772 [['Apple', 'ORG'], ['Tencent', 'ORG'], ['WeChat', 'ORG']]
# After a quick vacay 0.0 []
# Apple Oh cool ok. 0.5423 [['Apple', 'ORG']]
# Similar to when you hold down a message to add a text effect or heart it 0.0 []
# So uhhh who want it? Show me some love and maybe we'll drop it rap 0.5667 []
# Still kind of miss my pink phone -0.2247 []
# Camry now offers Apple Car Play support as a standard feature. Pair your compatible iPhone get directions 0.4019 [['Apple', 'ORG'], ['Car', 'PRODUCT'], ['Play', 'PRODUCT'], ['iPhone', 'PRODUCT']]
# So annoying that the latest update for AppleTv STILL does not fix photos on the 4K model. Disappointing. -0.7346 [['AppleTv', 'PRODUCT'], ['K', 'ORG']]
# I'm selling my iPhone 8. No scratches looks brand new.  -0.296 [['iPhone', 'PRODUCT']]
# IOS sucks -0.3612 [['IOS', 'SOFTWARE']]
# Can't wait to play music from my ass -0.6742 []
# I think Huawei is the best 0.6369 []
# Fr tho apple iphones heysiri cutthatshitout 0.0 [['apple', 'ORG']]
# I will never forgive for ruining the iPhone calculator app -0.0191 [['iPhone', 'PRODUCT']]
# So just read the requirements to apply for Settled Status. My wife does not have an android phone she swears by her iphone and sorry I'm not changing mobile contracts handsets and data plans just for a system that won't work. So now what happens? -0.0258 [['Settled', 'ORG'], ['Status', 'ORG'], ['android', 'SOFTWARE'], ['iphone', 'PRODUCT']]
# Do u still listen to music on iPod? Here is smarter iPod. 0.4588 [['iPod', 'PRODUCT'], ['iPod', 'PRODUCT']]
# Anyone know if has a new version of the airpods? I had the 1st ones when they came out in 2016 and misplaced them and am thinking of buying a new pair? 0.0 [['airpods', 'PRODUCT']]
# I dig this concept of iOS 13! It looks amazing! 0.658 [['iOS', 'SOFTWARE']]
# Got a new phone newphone. iPhone. 0.0 [['iPhone', 'PRODUCT']]
# Apple fails at autonomous vehicles -0.4215 [['Apple', 'ORG']]
# With simple touch screen interfaces 0.0 []
# If you are considering buying an iPhone X DON'T !!!!! Until they fix the issue where it constantly turns itself off and on mid call text email tweet save yourself this utter frustration. And NO the soft hard reset doesn't work! -0.6598 [['iPhone', 'PRODUCT']]
# Don't like their iPhone inspired software and don't really know about their software update commitment and how fast they update to latest Android version but don't think it's fast nor long support. -0.1386 [['iPhone', 'PRODUCT'], ['Android', 'SOFTWARE']]
# I was wrong about Google and Facebook: there s nothing wrong with them so say we all Thanks Aral! I agree with everything exposed here. Apple privacy. -0.3382 [['Google', 'ORG'], ['Apple', 'ORG']]
# Why would you downgrade to a phone that has the same resolution as a i Phone 4 0.0 []
# My 7 yo son was almost electrocuted the day after his birthday by an original apple charger that was provided by apple with the ipad! What he did was to try to unplug the charger! This is outrageous! Apple -0.3769 [['apple', 'ORG'], ['apple', 'ORG'], ['ipad', 'PRODUCT'], ['Apple', 'ORG']]
# Bought it for my daughter and she loves it! Red iPhone X Case for Valentine's Day! Buy now: The light liquid silicone fits snugly over the curves of your i Phone X without adding bulk Apple 0.6467 [['iPhone', 'PRODUCT'], ['Apple', 'ORG']]
# If iOS 13 looks like this 0.3612 [['iOS', 'SOFTWARE']]
# A lot of Mac users incorrectly believe that they are immune to malware;. This latest malvertising campaign targets Apple users with malicious code hidden in ad images 0.296 [['Mac', 'PRODUCT'], ['Apple', 'ORG']]
# And does it tell you that you can't update your apps 0.0 []
# I only updated my iPhone 5S because it started freezing -0.1027 [['iPhone', 'PRODUCT']]
# How to access your personal Apple Data 0.0 [['Apple', 'ORG']]
# I ve blocked someone but somehow the messages still come through to my Mac. How do I fix this? -0.1406 [['Mac', 'PRODUCT']]
# At first I was line wait how do they know which phone I have. Then the comments confirmed everyone gets it. 0.0 []
# Are you giving people a rent voucher? 0.34 []
# My battery dies at 50 wtf -0.5859 []
# What a bloody nuisance x -0.4404 []
# Mine was fine for a couple of months. Need to go to an apple shop but none nearby 0.1027 [['apple', 'ORG']]
# Apple have pissed me off cause I can t do any updates on my phone. I'm tempted to go back to my old phone -0.6369 [['Apple', 'ORG']]
# Is this real...? 0.0 []
# Still way too expensive!! 0.0 []
# I'm sticking with mine that I got in late 2016 0.0 []
# Yep 0.296 []
# iOS transparency looks awful and definitely needs improvement when using white or very light walls iOS 0.4019 [['iOS', 'SOFTWARE'], ['iOS', 'SOFTWARE']]
# I'm back and I'm betta Iphone is back on 0.0 [['Iphone', 'PRODUCT']]
# The Apple Epic talk doesn't make much sense for either side 0.0 [['Apple', 'ORG']]
# This will be the year of the Ear Pods 0.0 []
# Ain't it great how Apple ignores my browser preference when I search selected text in Messages? -0.6591 [['Apple', 'ORG']]
# Why isn't $500 per share with this amount of business?! -0.2914 []
# Im was not much a fan but since I exploit my macbook and other apple product Im in love 0.6926 [['macbook', 'PRODUCT'], ['apple', 'ORG']]
# Y'know 0.0 []
# Hey Apple 0.0 [['Apple', 'ORG']]
# I'm a happy i Phone XR owner and this is how Apple should sell it 0.5719 [['Phone', 'ORG'], ['XR', 'ORG'], ['Apple', 'ORG']]
# Interrupt this twitter silence for a cathartic twete: Apple's new macbook pros are absolute trash -0.34 [['Apple', 'ORG'], ['macbook', 'PRODUCT']]
# Ay man what s going on here 0.0 []
# Hey why is my phone dying faster than it s charging? 0.0 []
# They say the best camera is the one in your pocket. Shot On iPhone 0.6369 [['iPhone', 'PRODUCT']]
# Your brand new Apple product comes with one question 0.0 [['Apple', 'ORG']]
# Sounds like a lose lose situation.. That's ok I just left and my wallet is sitting on the counter. -0.1779 []
# My iPad's Keynote app may not be cooperating WiFi issue at a conference?!? but is setting this workshop on with so many cool activities with an iPad at Apple! 0.6499 [['iPad', 'PRODUCT'], ['iPad', 'PRODUCT'], ['Apple', 'ORG']]
# Wow so let me get this straight... I spend $334.78 on a pair of on Jan 12th 0.5859 []
# I'm ok with my 7 so far. Only replaced my 5s cause the screen was broken. -0.2263 []
# Dear how would you like me to walk into your office 0.6249 []
# Camara will be used for most of our content 0.0 []
# Apple's iOS 12.2 beta points to customized Downtime scheduling 0.0 [['Apple', 'ORG'], ['iOS', 'SOFTWARE'], ['Downtime', 'ORG']]
# My 5S was freezing and battery constant dying -0.1027 [['5S', 'ORG']]
# Judging from the trade in prices you're offering 0.0 []
# Now people are even losing self driving car jobs! Apple's dismissal of 200 self driving car employees points to a shift in its AI -0.4389 [['Apple', 'ORG']]
# It's shockingly easy it is to sideload iOS apps 0.296 [['iOS', 'SOFTWARE']]
# my phone is so slow and i ve literally had it for four months i'm suing -0.2732 []
# Battery was rubbish after 2.5years. Carried an emergency charger everywhere. Never froze that I remember. -0.3818 [['Battery', 'ORG']]
# LMAO what the hell 0.0085 []
# I agree with that 100 !! wouldnt that be something 0.4738 []
# It's too bad when I come to your store to spend $3 -0.5423 []
# For all talk of their fairness, and team had to wait for a public debate to do the right thing. That is different from what and team espouse about always doing the right thing. This shouldn t have happened to begin with! 0.0 []
# Good time long AAPL ; before earnings next Tuesday. Current 158. 0.4404 [['AAPL', 'ORG']]
# Who would like to Win; an ipadpro;? 1. Like our page 2. Retweet this post 3. Type 'done' in the comments. giveaway; competition; contest; free; prize; iphone; apple; gadgets; style; 0.9371 [['Type', 'ORG'], ['iphone', 'PRODUCT'], ['apple', 'ORG']]
# Price: $27.10 FREE Shipping casedeals;iphonecase;smartphonecases;samsungcases;xiaomicases;apple;huaweicase;cases; 0.6166 []
# Commissioned by A Great Day In Accra Series Shot Oni Phone; Ghana; Music; Africa; Hiplife; Apple; AG reat Day In Accra; 0.6249 [['Apple', 'ORG'], ['AG', 'ORG']]
# BRAND NEW RELEASE Dinosaur Safari: Evolution Mac Version Visit Mac App Store now to download for FREE Click Copy below link for FREE download dinosaur; dino; jurassic; jurassicpark; jurassicworld; assassin; mac; iphone; ipad; hunt; world; 0.8429 [['Mac', 'PRODUCT'], ['Mac', 'PRODUCT'], ['FREE', 'ORG'], ['mac', 'PRODUCT'], ['iphone', 'PRODUCT'], ['ipad', 'PRODUCT']]
# Mmm.... I bet that guitar sure sounds great through that USB plug... 0.7506 [['USB', 'ORG']]
# Apple shares rally 0.296 [['Apple', 'ORG']]
# Very annoying... Hope you manage to get it sorted 0.4902 []
# Someone make this into a revamp i Pod commercial 0.0 []
# I have an X on Vodafone and I ve not hand any issues likes yours 0.0444 []
# A child starting the new school year without the items on their stationery list or a vital iPad; may never achieve their educational potential. Help a child reach for the stars by donating to GIVITs Back to School appeal 0.6124 [['iPad', 'PRODUCT']]
# I hate the OS X upgrade popups -0.5719 [['OS', 'ORG']]
# Just dont buy apple simples. Samsung all the way.. 0.0 [['apple', 'ORG'], ['Samsung', 'ORG']]
# Not so much going after 0.0 []
# Worked fine for a couple of months. Recently started doing this but today it has worked for about two minutes at a time 0.1027 []
# Apple's latest Watch can Sense Falls and Heart Irregularities Healthcare 0.0 [['Apple', 'ORG'], ['Watch', 'PRODUCT']]
# If NOKIA and blackberry can collapse than so can FB and Whatsapp. Arrogance and wrong decisions have caused the demise of many empires. -0.8658 [['NOKIA', 'ORG']]
# If I'm the US taxpayer You pay for decades -0.1027 []
# The ear is accurate 0.0 []
# Tried all the resets. Been told to take it back and I will. Potentially won't be leaving with the phone as it's been so frustrating -0.5777 []
# Or just use icloud for mail. At least 0.0 [['icloud', 'SERVICE']]
# I can't wait for my new phone 0.0 []
# So calls u now to tell u someone is tryna hack your iCloud 0.0 [['iCloud', 'SERVICE']]
# I got a cool idea for you guys I think the ipad pro should have a diffrent OS Maybe mac OS but thats too good to be true. Maybe A new OS Pad OS a bridge between IOS and mac OS. Its just a watered down mac OS with fitting specs and support for wireless mouse and keyboard 0.9144 [['ipad', 'PRODUCT'], ['OS', 'ORG'], ['mac', 'PRODUCT'], ['OS', 'ORG'], ['OS', 'ORG'], ['Pad', 'ORG'], ['OS', 'ORG'], ['IOS', 'SOFTWARE'], ['mac', 'PRODUCT'], ['OS', 'PRODUCT'], ['mac', 'PRODUCT'], ['OS', 'PRODUCT']]
# Rob -0.5574 []
# For me the samsung works really well. I feel it's very simple and easy to use as well. Updates seem to aid the use rather than hinder it. 0.7876 []
# If I'm going to overpay for something I'll just go to a movie in Southern California 0.0 []
# Nine years ago today 0.0 []
# Apple must provide a man access to the iCloud account of his late husband so he can retrieve family photos shot with an iPhone and a dedicated camera 0.4588 [['Apple', 'ORG'], ['iCloud', 'SERVICE'], ['iPhone', 'PRODUCT']]
# I paid $5000 for a top of the line Macbook Pro and it's utterly useless because it cannot keep it self cooled down -0.3167 [['Macbook', 'PRODUCT']]
# Tim Cook mingles with Microsoft s Satya Nadella at World Economic Forum, touts Apple s education ambitions 9to5 Mac apple; -0.0258 [['Microsoft', 'ORG'], ['Satya', 'ORG'], ['Nadella', 'ORG'], ['Apple', 'ORG'], ['Mac', 'PRODUCT'], ['apple', 'ORG']]
# Thank you for the quality you sell. In less than 2 years my laptop died and now it's totally broken for no reason. The price is unacceptable. -0.4588 []
# yo no one cares if I can make fireworks in the text lemme set a goddamn away message -0.3182 []
# Reportedly Apple's next lower end iPad won't feature Face ID -0.296 [['Apple', 'ORG'], ['iPad', 'PRODUCT']]
# can you tell me if you still replace iPhone SE batteries? 0.0 [['iPhone', 'PRODUCT']]
# When you wish you'd taken the time to learn Mac 0.4019 [['Mac', 'PRODUCT']]
# My auto pause is turned off 0.0 []
# Apple i OS 12.1.3 Release Has A Nasty Surprise NBD it will just shut off cellular reception and possibly disable WiFi... I'm sure it will still take blurry pictures... 0.347 [['Apple', 'ORG'], ['OS', 'ORG']]
# Be honest 0.5106 []
# Things I wish my iphone; would do... 1. Voice recognize take a selfie and actually TAKE THE SELFIE . 2. Let me leave a video message on facetime. Thank you for your time. 0.6124 [['iphone', 'PRODUCT']]
# I slur aayyy Google and it gets what I'm saying 99 of the time. Just saying. 0.0 [['Google', 'ORG']]
# Question on Quora: Which payment platform is safer; Apple Pay; or Google Pay;? apple; google; 0.34 [['Apple', 'ORG'], ['Pay', 'PRODUCT'], ['Google', 'ORG'], ['apple', 'ORG'], ['google', 'ORG']]
# so just read the requirements to apply for Settled Status. My wife does not have an android phone she swears by her iphone; and sorry I'm not changing mobile contracts handsets and data plans just for a system that won't work brexitshambles; builttofail; so now what happens? -0.0258 [['Settled', 'ORG'], ['Status', 'ORG'], ['android', 'SOFTWARE'], ['iphone', 'PRODUCT']]
# Hi 0.0 []
# Who the f k at ever decided the sort option for cellular data screen in iOS should be by amount used should be drawn and quartered scroll up down 0.0 [['iOS', 'SOFTWARE']]
# when will you fix the airpods cutting out issue on macbooks? I need to manually change reset bluetooth and restart everytime I want to use it... -0.0516 [['airpods', 'PRODUCT']]
# I'm sure this is not how you expected your Apple products to be displayed in a department store! 0.3802 [['Apple', 'ORG']]
# Yo you guys need to let us quote messages separately to reply on iMessage 0.0 []
# Hi 0.0 []
# You need to fix the issue on snapchat with iphone X 0.0 [['iphone', 'PRODUCT']]
# How u drop an 7th Ipod Touch after 4 YRS your still 4 IN screen? Apple stock should drop. -0.4939 [['Ipod', 'PRODUCT'], ['Apple', 'ORG']]
# Pay $500 for a $750 phone that should've been $500 at best in the first place. 0.5859 []
# I know it's tough once you get sucked into the Apple ecosystem but -0.3071 [['Apple', 'ORG']]
# only just upgraded my Mac Book to Mojave! and it fixed my security software issue too! 0.4559 [['Mac', 'PRODUCT']]
# i just love this government wanting to create an environment so hostile you need to go and buy a high end android phone 0.4467 [['android', 'SOFTWARE']]
# is there a technical reason the i Phone 8 cant download 4K files from the OSMO? Is it a hardware or iOS issue? 0.0 [['K', 'ORG'], ['OSMO', 'ORG'], ['iOS', 'SOFTWARE']]
# iphone giveaway To Enter: 1. Retweet 2. Follow us 3. Turn Notifications on Winner in one days Good Luck giveaway; apple; iphone; 0.8658 [['iphone', 'PRODUCT'], ['apple', 'ORG'], ['iphone', 'PRODUCT']]
# If you ditch Apple for the far superior Samsung you can have yourself a holiday with the money you save. 0.8555 [['Apple', 'ORG'], ['Samsung', 'ORG']]
# The launch of the original iPad on January 27 0.3182 [['iPad', 'PRODUCT']]
# Am I the only one that has a weak ass battery for my Iphone8 Plus?? Its been draining SO fast the past week or two I use my mobile hotspot listen to music for legit 45 minutes and my battery goes from 100 to 30 how where can I get a new battery -0.7757 []
# I think he's making the point that in both cases it appears to be all about what's best for Apple. I can't recall a more aggressively selfish and bull headed company in recent times 0.4589 [['Apple', 'ORG']]
# Feature request: The ability to turn handwritten text to digital text 0.3182 []
# Apple's greed astounds me. 0.1027 [['Apple', 'ORG']]
# I own an IPhone XS Max and my cousin have a Google pixel 3xl and I know for a fact this is NOT fake advertising. This is the sad true. I pay $200 more for my iPhone but his phone take way better pictures. Please do something about that. Thanks 0.9017 [['IPhone', 'PRODUCT'], ['Google', 'ORG'], ['iPhone', 'PRODUCT']]
# OK  0.296 []
# Im staring to dislike Apple as a company. -0.3818 [['Apple', 'ORG']]
# Apple iOS 12.1.3 Release Has A Nasty Surprise Forbes -0.3612 [['Apple', 'ORG'], ['iOS', 'SOFTWARE']]
# When you guys are going to fix 0.0 []
# Since updating my i Phone Xs Max to iOS 12.1.3 0.0 [['iOS', 'SOFTWARE']]
# The camera of the i Phone XS Max is incredible  0.0 []
# sticking with my 8 till I see a real jump in tech or a big drop in price. Just not worth upgrading. XR too expensive. XS just silly. -0.3952 []
# I know the iPad we bought is junk! It s not the pro .... the 500 dollar one for people who don t need pro....just Facebook 0.0 [['iPad', 'PRODUCT']]
# Don't be like Adam & Eve Apple -0.2755 [['Adam', 'ORG'], ['&', 'ORG'], ['Eve', 'ORG'], ['Apple', 'ORG']]
# what we need is a way to lock 15 20 of our fav emojis so they are always there.. its what the people need. 0.4588 []
# Someone needs to design a hat or headband specifically designed to keep s poorly designed well it fits some people ok Airpods in one's earholes. 0.5106 [['Airpods', 'PRODUCT']]
# We have the Mac Book with faulty keyboard... Telse -0.3182 [['Mac', 'PRODUCT']]
# Sod off and take your overpriced 0.0 []
# After 30 minutes on the phone with and another hour in a store 0.0 []
# This whole episode has me questioning my loyalty to Apple. 0.4767 [['Apple', 'ORG']]
# All Android phones are good but IOS sucks -0.3182 [['Android', 'SOFTWARE'], ['IOS', 'SOFTWARE']]
# Excuse my funky ass iPhone but here is a snippet of DeAnt Amazing Prod By. I'm sick as well so this won't be released until I'm better I'm not recording a song sick. It's impossible. My ass already got asthma -0.6428 [['iPhone', 'PRODUCT'], ['DeAnt', 'ORG'], ['Amazing', 'ORG'], ['Prod', 'ORG']]
# I need the battery shortcut on the control panel please 0.3182 []
# I got rid of my i Phone 6 because when you update and a new phone is launched the updates mess with ur phone it freezes -0.2732 []
# Hey 0.0 []
# My phone can't connect to my service wtf thx -0.3182 []
# I absolutely LOVE these FUNCL AI wireless smart headphones. Battery life for days... literally superior sound quality. If you are considering Air Pods or any ear buds get these. Half the price of Air Pods and better specs. I just ordered another pair in black! 0.9395 [['Air', 'ORG'], ['Pods', 'ORG'], ['Air', 'ORG'], ['Pods', 'ORG']]
# My iPad isn t charging. I've tried different plugs and cables 0.0 [['iPad', 'PRODUCT']]
# Soooo my mom bought an iPad and she's new to Apple and iPads so she couldn't figure out how to unlock her iPad with her fingerprint and this is why.... 0.0 [['iPad', 'PRODUCT'], ['Apple', 'ORG'], ['iPad', 'PRODUCT']]
# That latest facetime hack that lets people listen to you just shows that all your devices HAVE been listening to EVERYTHING you do or say around it.  0.0 []
# Now you can answer for yourself on Face Time even if they don't answer Apple explain this.. 0.0 [['Apple', 'ORG']]
# I had a to do list for today. But thanks to my MacBook dying none of it got done because I spent 12 hours trying every apple trick in the book to get it to work 0.5499 [['MacBook', 'PRODUCT'], ['apple', 'ORG']]
# If a mf do this they getting blocked so it really don't matter -0.3511 []
# Reid lookin so good in his Air Pods 0.5777 [['Reid', 'ORG'], ['Air', 'ORG'], ['Pods', 'ORG']]
# thanks alot for adding much awaited turn by turn navigation for India. It looks cool details are vibrant while driving and walking The best part is I can book in Applemaps 0.9136 []
# On Monday 0.0 []
# my phone still isn't working.... 0.0 []
# Please consider putting camera LED lights and microphone lights for privacy on all your phones. So we know when they are on. 0.3182 []
# Apple's drop shouldn t be seen as an epitome for the state of the Chinese economy. Now -0.2732 [['Apple', 'ORG']]
# if you remove 3D Touch I will never buy an i Phone again 0.0 []
# Fuck snapchat -0.5423 []
# The bug won't be fixed 0.0 []
# Nah....she just giving all our information to Apple 0.34 [['Apple', 'ORG']]
# I was subscribed on Apple Podcasts but that app interface is hot garbage in my opinion no disrespect but I much prefer Spotify. -0.7579 [['Apple', 'ORG'], ['Spotify', 'PRODUCT']]
# REALLY ABOUT TO DRAG FOR A WHOLE ASS VIDEO THEN FOR NO REASON AT ALL DRAG ANDROID PHONES??? -0.8614 [['ANDROID', 'SOFTWARE']]
# Who the fuck uses Face Time in 2019. -0.5423 []
# Apple Fuck off -0.5423 [['Apple', 'ORG']]
# Probably until they fix the update. 0.0 []
# Thank you so much. Cannot thank you enough. Now anything does on iOS has to go through App Store review 0.0326 [['iOS', 'SOFTWARE'], ['App', 'ORG'], ['Store', 'ORG']]
# Get a new phone 0.0 []
# The XR has a bad camera -0.5423 [['XR', 'ORG']]
# iMessage should have a nightmode 0.0 []
# If you want the option to set auto lock to never please consider getting an Android! Thank you for choosing Apple! 0.3447 [['Android', 'SOFTWARE'], ['Apple', 'ORG']]
# Hi Apple! Welcome to 2016! 0.555 [['Apple', 'ORG']]
# Get Android 0.0 [['Android', 'SOFTWARE']]
# Apple 0.0 [['Apple', 'ORG']]
# Apple Get The Fuck Outta Here -0.5423 [['Apple', 'ORG']]
# If you want your phone to look like this 0.4215 []
# WARNING Dear iPhone Users -0.1363 [['iPhone', 'PRODUCT']]
# Apple has acknowledged a flaw in its Face Time software that allows brief eavesdropping. Has this put you off? Does this flaw raise more questions about how secure your device is? Get in touch BBCB iz Live 0.4137 [['Apple', 'ORG'], ['BBCB', 'ORG']]
# Apple users beware! Facetime on iOS can allow people to see through your video camera or mic even if the caller doesn't pick up!  0.3578 [['Apple', 'ORG'], ['iOS', 'SOFTWARE']]
# Nothing is turned on that is in this house 0.0 []
# PSA I need to have a search for emojis and ALSO more emojis 0.0 []
# I'm not buying a new iPhone until offers a smaller form factor with modern internals. cough iPhone SE 2 cough 0.0 [['iPhone', 'PRODUCT'], ['iPhone', 'PRODUCT']]
# I wanna be that guy and say switch brands because mama said Apple is the devil -0.6597 [['Apple', 'ORG']]
# I don t care about having the best camera 0.8126 []
